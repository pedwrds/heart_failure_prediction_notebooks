# %%
# reconstructing lost file

# %%
from hfpred.utils import get_project_root
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

from sklearn.model_selection import cross_validate
from sklearn.metrics import SCORERS, make_scorer, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

import dataframe_image as dfi
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Candidate Models [Parameter Tuning with Cross-Validation]
# * idea here is to train candidate models and using more robust cross validation for analysing performance
# * select best models (when applied to the validation set) to take part in a popular voting classifier

# %% [markdown]
# ### Can use the training and validatinon set combined
# * train models and optimise hyperparameters using cross validation using the train and val set combined

# %%
df = pd.read_csv(
    get_project_root() / "data/heart-processed.csv",
    index_col=0
)
print(f"dataset instances: {len(df)}")
df.tail()
# Out:
# dataset instances: 671
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  Sex_M  \
# 209  0.530612   0.305556     0.252896        0.0  0.533835  0.015873      1
# 704  0.448980   0.537037     0.305019        0.0  0.443609  0.428571      1
# 665  0.285714   0.407407     0.444015        0.0  0.421053  0.301587      1
# 447  1.000000   0.296296     0.166023        0.0  0.308271  0.333333      1
# 907  0.326531   0.259259     0.162162        0.0  0.563910  0.460317      1
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 209                  1                  0                  0
# 704                  1                  0                  0
# 665                  1                  0                  0
# 447                  1                  0                  0
# 907                  1                  0                  0
#
#      RestingECG_Normal  ExerciseAngina_N  ST_Slope_Down  ST_Slope_Flat  \
# 209                  1                 1              0              1
# 704                  0                 1              0              1
# 665                  1                 0              0              1
# 447                  0                 0              0              0
# 907                  1                 0              1              0
#
#      ST_Slope_Up  HeartDisease train/val
# 209            0             1       val
# 704            0             1       val
# 665            0             1       val
# 447            1             1       val
# 907            0             1       val

# %%
df.drop(
    columns="train/val",
    inplace=True
)

# split attributes and target:
cols = list(df.columns)
cols.pop(cols.index("HeartDisease"))

x_train = df[cols]
y_train = df["HeartDisease"]

# %% [markdown]
# ## 10-Fold Cross-Validation for Default Model Parameters

# %%
def fit_model(model, x, y):
    model.fit(x, y)

def cv_model(model, x, y, name):
    df = pd.DataFrame(
        cross_validate(
            model,
            x,
            y,
            cv=10,
            scoring=[
                "accuracy",
                "recall",
                "precision",
                "f1",
                "roc_auc"
            ]
        )
    )
    
    df = df.mean().to_frame().transpose()
    df.rename(index={0:f"{name}"}, inplace=True)

    return df

# %%
models = {
    "kNN": KNeighborsClassifier(),
    "SVM Classifier": SVC(),
    "Random Forest Classifier": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "XGBoost": XGBClassifier(),
}

# %%
cv_models = pd.DataFrame()

for name, model in models.items():
    np.random.seed(13)
    fit_model(model, x_train, y_train)
    model_cv = cv_model(model, x_train, y_train, name)

    cv_models = pd.concat([cv_models, model_cv])

cv_models
# Out:
#                           fit_time  score_time  test_accuracy  test_recall  \
# kNN                       0.002037    0.008451       0.837555     0.853314
# SVM Classifier            0.007523    0.006870       0.853973     0.878314
# Random Forest Classifier  0.095831    0.017807       0.864399     0.871970
# Logistic Regression       0.007003    0.003900       0.862906     0.872159
# XGBoost                   0.043735    0.007190       0.836084     0.847159
#
#                           test_precision   test_f1  test_roc_auc
# kNN                             0.817177  0.833124      0.896764
# SVM Classifier                  0.828329  0.851440      0.918225
# Random Forest Classifier        0.851809  0.859776      0.925344
# Logistic Regression             0.846404  0.857681      0.924245
# XGBoost                         0.819992  0.832006      0.905598

# %%
cv_models.drop(
    columns=[
        "fit_time",
        "score_time"
    ],
    inplace=True
)

# %%
# dfi.export(
#     cv_models,
#     "../output/tables/cv_def_models.png"
# )

# %%
# need class weights for some parameter tuning:
train_class_weights = {
    0: y_train.value_counts()[0],
    1: y_train.value_counts()[1]
}
train_class_weights
# Out:
# {0: 350, 1: 321}

# %% [markdown]
# ## Hyperparameter Tuning
# * will use cross validation and recall as a scoring metric to tune select model parameters.

# %% [markdown]
# ### SVM Classifier Tuning

# %%
svc_hparams = {
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
    "C": [100, 10, 1, 0.1, 0.01, 0.001],
    "degree": [2, 3, 4, 5], # ignored by all but poly kernel
    "class_weight": [None, "balanced", train_class_weights]
}

# %%
svc_search = pd.DataFrame()

gs_svc = GridSearchCV(
    SVC(),
    svc_hparams,
    cv=5,
    scoring="recall",
)
gs_svc.fit(x_train, y_train)
svc_search.at[gs_svc.best_estimator_, "recall"]= gs_svc.best_score_

# %%
svc_search
# Out:
#                                                       recall
# SVC(C=0.001, class_weight='balanced', degree=4,...  0.925192

# %%
np.random.seed(13)
# svc_model = SVC(C=0.001, class_weight='balanced', degree=4, kernel='poly')
svc_model = gs_svc.best_estimator_
fit_model(svc_model, x_train, y_train)
opt_svc = cv_model(svc_model, x_train, y_train, str(svc_model))
# print(str(svc_model))
opt_svc
# Out:
#                                                     fit_time  score_time  \
# SVC(C=0.001, class_weight='balanced', degree=4,...  0.010365    0.005764
#
#                                                     test_accuracy  \
# SVC(C=0.001, class_weight='balanced', degree=4,...       0.831585
#
#                                                     test_recall  \
# SVC(C=0.001, class_weight='balanced', degree=4,...     0.925095
#
#                                                     test_precision   test_f1  \
# SVC(C=0.001, class_weight='balanced', degree=4,...        0.770966  0.840211
#
#                                                     test_roc_auc
# SVC(C=0.001, class_weight='balanced', degree=4,...      0.913109

# %%
# # save trained tuned model:
# svc_path = get_project_root() / "models/svc.joblib"
# joblib.dump(svc_model, svc_path)

# %% [markdown]
# ### Random Forest Tuning

# %%
rf_hparams = {
    "max_features": ["sqrt", "log2"],
    "min_samples_leaf": [1, 2, 3, 5],
    "n_estimators": [10, 100, 1000],
    "bootstrap": [True, False],
}

# %%
np.random.seed(13)
rf_search = pd.DataFrame(columns=["recall"])

gs_rf = GridSearchCV(
    RandomForestClassifier(),
    rf_hparams,
    cv=5,
    scoring="recall",
)

gs_rf.fit(x_train, y_train)
rf_search.at[str(gs_rf.best_estimator_).replace("\n",""), "recall"]= gs_rf.best_score_

# %%
rf_search
# Out:
#                                                       recall
# RandomForestClassifier(max_features='sqrt', min...  0.881442

# %%
np.random.seed(13)
rf_model = gs_rf.best_estimator_
fit_model(rf_model, x_train, y_train)
opt_rf = cv_model(rf_model, x_train, y_train, str(rf_model))
opt_rf
# Out:
#                                                     fit_time  score_time  \
# RandomForestClassifier(max_features='sqrt', min...  0.097798    0.019007
#
#                                                     test_accuracy  \
# RandomForestClassifier(max_features='sqrt', min...       0.861348
#
#                                                     test_recall  \
# RandomForestClassifier(max_features='sqrt', min...     0.881345
#
#                                                     test_precision   test_f1  \
# RandomForestClassifier(max_features='sqrt', min...        0.836879  0.857671
#
#                                                     test_roc_auc
# RandomForestClassifier(max_features='sqrt', min...      0.929957

# %%
# # save trained tuned model:
# rf_path = get_project_root() / "models/rf.joblib"
# joblib.dump(rf_model, rf_path)

# %% [markdown]
# ### Logistic Regression Tuning

# %%
lr_hparams = {
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
    "penalty": ["l1", "l2", "elasticnet"],
    "C": [10, 1.0, 0.1, 0.01],
}

# %%
lr_search = pd.DataFrame()

gs_lr = GridSearchCV(
    LogisticRegression(),
    lr_hparams,
    cv=5,
    scoring="recall",
)
gs_lr.fit(x_train, y_train)

lr_search.at[str(gs_lr.best_estimator_).replace("\n",""), "recall"]= gs_lr.best_score_
# Out:
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 160 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 457, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/envs/hfpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.87841346        nan 0.87841346 0.87841346
#  0.87841346 0.87216346 0.87841346 0.87841346        nan        nan
#         nan        nan        nan        nan        nan 0.87216346
#         nan 0.86596154 0.87216346 0.87216346 0.87533654 0.87216346
#  0.87216346        nan        nan        nan        nan        nan
#         nan        nan 0.85350962        nan 0.85975962 0.87836538
#  0.87836538 0.88149038 0.87836538 0.87836538        nan        nan
#         nan        nan        nan        nan        nan 0.
#         nan 0.         0.85341346 0.85341346 0.86899038 0.85341346
#  0.85341346        nan        nan        nan        nan        nan]
#   warnings.warn(

# %%
lr_search
# Out:
#                                                 recall
# LogisticRegression(C=0.1, solver='liblinear')  0.88149

# %%
lr_model = gs_lr.best_estimator_
fit_model(lr_model, x_train, y_train)
opt_lr = cv_model(lr_model, x_train, y_train, str(lr_model))
opt_lr
# Out:
#                                                fit_time  score_time  \
# LogisticRegression(C=0.1, solver='liblinear')   0.00216    0.004298
#
#                                                test_accuracy  test_recall  \
# LogisticRegression(C=0.1, solver='liblinear')       0.862862     0.881345
#
#                                                test_precision   test_f1  \
# LogisticRegression(C=0.1, solver='liblinear')        0.840203  0.858726
#
#                                                test_roc_auc
# LogisticRegression(C=0.1, solver='liblinear')      0.921737

# %%
# # save trained tuned model:
# lr_path = get_project_root() / "models/opt_lr.joblib"
# joblib.dump(lr_model, lr_path)

# %% [markdown]
# ### XGBoost Tuning

# %%
xgb_hparams = {
    "objective": ["reg:squarederror", "binary:logistic"],
    "max_depth": [3, 5, 7, 9], 
    # "colsample_bylevel": [0.5],
    "learning_rate": [0.01, 0.05, 0.1, 0.5],
    "random_state": [13]
}

# %%
xgb_search = pd.DataFrame()

gs_xgb = GridSearchCV(
    XGBClassifier(),
    xgb_hparams,
    cv=5,
    scoring="recall",
)
gs_xgb.fit(x_train, y_train)

xgb_search.at[str(gs_xgb.best_estimator_).replace("\n",""), "recall"]= gs_xgb.best_score_

# %%
xgb_search
# Out:
#                                                      recall
# XGBClassifier(base_score=0.5, booster='gbtree',...  0.88149

# %%
xgb_model = gs_xgb.best_estimator_
fit_model(xgb_model, x_train, y_train)
opt_xgb = cv_model(xgb_model, x_train, y_train, str(xgb_model).replace("\n",""))
opt_xgb
# Out:
#                                                     fit_time  score_time  \
# XGBClassifier(base_score=0.5, booster='gbtree',...  0.074152    0.008376
#
#                                                     test_accuracy  \
# XGBClassifier(base_score=0.5, booster='gbtree',...       0.846532
#
#                                                     test_recall  \
# XGBClassifier(base_score=0.5, booster='gbtree',...     0.875189
#
#                                                     test_precision   test_f1  \
# XGBClassifier(base_score=0.5, booster='gbtree',...        0.818602  0.844451
#
#                                                     test_roc_auc
# XGBClassifier(base_score=0.5, booster='gbtree',...      0.920928

# %%
# # save trained tuned model:
# xgb_path = get_project_root() / "models/xgb.joblib"
# joblib.dump(xgb_model, xgb_path)

# %%
opt_models = pd.concat(
    [
        opt_svc,
        opt_rf,
        opt_lr,
        opt_xgb
    ]
)
opt_models
# Out:
#                                                     fit_time  score_time  \
# SVC(C=0.001, class_weight='balanced', degree=4,...  0.010365    0.005764
# RandomForestClassifier(max_features='sqrt', min...  0.097798    0.019007
# LogisticRegression(C=0.1, solver='liblinear')       0.002160    0.004298
# XGBClassifier(base_score=0.5, booster='gbtree',...  0.074152    0.008376
#
#                                                     test_accuracy  \
# SVC(C=0.001, class_weight='balanced', degree=4,...       0.831585
# RandomForestClassifier(max_features='sqrt', min...       0.861348
# LogisticRegression(C=0.1, solver='liblinear')            0.862862
# XGBClassifier(base_score=0.5, booster='gbtree',...       0.846532
#
#                                                     test_recall  \
# SVC(C=0.001, class_weight='balanced', degree=4,...     0.925095
# RandomForestClassifier(max_features='sqrt', min...     0.881345
# LogisticRegression(C=0.1, solver='liblinear')          0.881345
# XGBClassifier(base_score=0.5, booster='gbtree',...     0.875189
#
#                                                     test_precision   test_f1  \
# SVC(C=0.001, class_weight='balanced', degree=4,...        0.770966  0.840211
# RandomForestClassifier(max_features='sqrt', min...        0.836879  0.857671
# LogisticRegression(C=0.1, solver='liblinear')             0.840203  0.858726
# XGBClassifier(base_score=0.5, booster='gbtree',...        0.818602  0.844451
#
#                                                     test_roc_auc
# SVC(C=0.001, class_weight='balanced', degree=4,...      0.913109
# RandomForestClassifier(max_features='sqrt', min...      0.929957
# LogisticRegression(C=0.1, solver='liblinear')           0.921737
# XGBClassifier(base_score=0.5, booster='gbtree',...      0.920928

# %%
# dfi.export(
#     opt_models,
#     "../output/tables/opt_models.png"
# )

# %%
opt_models.rename(
    index={
        str(xgb_model).replace("\n",""):
        "XGBClassifier(objective='reg:squarederror', max_depth=3, learning_rate=0.01, random_state=13)"
    },
    inplace=True
)

opt_models.drop(
    columns=[
        "fit_time",
        "score_time"
    ],
    inplace=True
)

# %%
# dfi.export(
#     opt_models,
#     "../output/tables/opt_models.png"
# )

# %%
opt_mods = opt_models.head(3)

# %%
# dfi.export(
#     opt_mods,
#     "../output/tables/opt_3_models.png"
# )
